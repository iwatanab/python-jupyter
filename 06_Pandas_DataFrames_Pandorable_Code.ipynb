# %% [markdown]
# # Pandas DataFrames: Writing Pandorable Code

# %%
import pandas as pd

census = pd.read_excel('Data\census.xlsx')
census.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %% [markdown]
# ## #1 Avoid Chain Indexing ']['

# %% [markdown]
# df.loc['Wastenaw']['Total Polulation'] This will pull the rows with the index 'Washtenaw' and only the 'Total Pollution' Column If you see a ][ you should think carefully about what you are doing.
#
# - loc is label-based. This means that if you write loc[2], you are looking for the values of your DataFrame that have an index labeled 2.
# - iloc is position-based. This means that if you write iloc[2], you are looking for the values of your DataFrame that are at index 2.

# %%
#Remember, a dataframe is a a stack of series.
#The code below pulls the first row based on it's index
census.iloc[0].head()
# Out:
# SUMLEV      40
# REGION       3
# DIVISION     6
# STATE        1
# COUNTY       0
# Name: 0, dtype: object

# %%
#The code below pulls the first row based on it's label
census.set_index(['STNAME','CTYNAME'], inplace = True)
census.loc[('Alabama','Autauga County')]
# Out:
# C:\Users\iwatanabe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#
#                         POPESTIMATE2011  POPESTIMATE2012     ...       \
# STNAME  CTYNAME                                              ...
# Alabama Autauga County            55253            55175     ...
#
#                         RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME  CTYNAME
# Alabama Autauga County          7.242091         -2.915927         -3.012349
#
# ...

# %%
#The following code pulls the DIVISON and CENSUS2010POP for Autauga County in Alabama
#Note the structure [Row Label, Column Label]
# .loc[ROW LABEL, COLUMN INDEX] will not work (e.g. census.loc[('Alabama','Autauga County'),[1:4] )
census.loc[('Alabama','Autauga County'),['DIVISION','CENSUS2010POP']]
# Out:
# C:\Users\iwatanabe\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1472: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)
#                         DIVISION  CENSUS2010POP
# STNAME  CTYNAME
# Alabama Autauga County         6          54571

# %%
census.iloc[0,1:4]
# Out:
# REGION      3.0
# DIVISION    6.0
# STATE       1.0
# Name: (Alabama, Alabama), dtype: float64

# %% [markdown]
# ## #2 Chain your Methods using 1) Parentheses, and 2) New Lines

# %% [markdown]
# In python if you begin with an open parenthesis you can span a statement over multiple lines

# %%
(
    census.where(census['SUMLEV'] == 50)
        .dropna()
        .set_index(['STNAME','CTYNAME'])
        .rename(columns={'ESTIMATESBASE2010':'Estimates Base 2010'})
        .head()
)
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County    50.0     3.0       6.0    1.0     1.0
#         Baldwin County    50.0     3.0       6.0    1.0     3.0
#         Barbour County    50.0     3.0       6.0    1.0     5.0
#         Bibb County       50.0     3.0       6.0    1.0     7.0
#         Blount County     50.0     3.0       6.0    1.0     9.0
#
#                         CENSUS2010POP  Estimates Base 2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County        54571.0              54571.0          54660.0
#         Baldwin County       182265.0             182265.0         183193.0
#         Barbour County        27457.0              27457.0          27341.0
#         Bibb County           22915.0              22919.0          22861.0
#         Blount County         57322.0              57322.0          57373.0
#
#                         POPESTIMATE2011  POPESTIMATE2012     ...       \
# ...

# %% [markdown]
# ## #3 Apply Functions to Rows in a DataFrame Using apply()

# %%
# Say we want to get the minimum and maximum values for the population estimate across the years

import numpy as np

# Quick note: How to pull multiple columns from a DataFrame
# THIS WILL FAIL: census['POPESTIMATE2010','POPESTIMATE2011']
# You must wrap the multiple column names in a list
census[['POPESTIMATE2010','POPESTIMATE2011']].head()
# Out:
#                         POPESTIMATE2010  POPESTIMATE2011
# STNAME  CTYNAME
# Alabama Alabama                 4785161          4801108
#         Autauga County            54660            55253
#         Baldwin County           183193           186659
#         Barbour County            27341            27226
#         Bibb County               22861            22733

# %%
def min_max(row):
    data = row[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']]
    return pd.Series({'min':np.min(data), 'max':np.max(data)})

aa = census.apply(min_max, axis=1).head() #Takes the series 
#returned for each row, flips them 90 degrees clockwise and stacks them
aa.head()
# Out:
#                               min        max
# STNAME  CTYNAME
# Alabama Alabama         4785161.0  4858979.0
#         Autauga County    54660.0    55347.0
#         Baldwin County   183193.0   203709.0
#         Barbour County    26489.0    27341.0
#         Bibb County       22512.0    22861.0

# %%
# As you would expect, we can use lamba function in the apply method
rows = ['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']

census.apply(lambda x: np.max(x[rows]), axis=1).head()
# Out:
# STNAME   CTYNAME
# Alabama  Alabama           4858979.0
#          Autauga County      55347.0
#          Baldwin County     203709.0
#          Barbour County      27341.0
#          Bibb County         22861.0
# dtype: float64
