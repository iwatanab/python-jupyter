# %% [markdown]
# # Pandas DataFrames: Reading, Indexing, and Querying

# %%
import pandas as pd
import numpy as np
# The dataframe data structure is the HEART OF THE PANDAS LIBRARY
# Dataframes are simply 2-axis, lebeled arrays with a special class-type that allows us to use pandas methods on them.

#                   Animals   Owners    <----- .columns
# .iloc, .loc -> 0   Dog      Chris
#                1   Cat      Kevyn <--- Values
#                2   Bear     Bob

# NOTE: we know .iloc and .loc are attributes. So is .columns

# QUESTION 1: HOW WOULD YOU PULL ROW 2?
# pet_df.iloc[1]

# QUESTION 2: HOW YOU YOU PULL THE OWNER'S COLUMN?
# pet_df["Owners"]

# QUESTION 3: FIND OUT WHAT ANIMAL IS ON THE THIRD RECORD
# pet_df.iloc[2]["Animals"]

# %%
# Transation 1: SERIES MADE FROM A DICTIONARY 
# Remember, dictionaries are Key:value pairs. THe Keys in the dicitonary are assigned as label indexes when converted to a Series

transaction_1 = pd.Series({'Name': 'Chris',
                          'Item Purchased': 'Dog Food',
                          'Cost': 22.50})

#Transaction 2: A series made from a dictionary
transaction_2 = pd.Series({'Name': 'Jeremiah',
                'Item Purchased': 'Cucumber',
                'Cost': 0.75})

# Transaction 3: A series made from a dictionary
transaction_3 = pd.Series({'Name': 'Isaiah',
                          'Item Purchased': 'Coffee',
                          'Cost': 2.30})

# %%
print(transaction_1)
# Out:
# Name                 Chris
# Item Purchased    Dog Food
# Cost                  22.5
# dtype: object

# %%
print(transaction_2)
# Out:
# {'Name': 'Jeremiah', 'Item Purchased': 'Cucumber', 'Cost': 0.75}

# %%
print(transaction_3)
# Out:
# Name              Isaiah
# Item Purchased    Coffee
# Cost                 2.3
# dtype: object

# %%
# First let's create the dataframe without row index labels
dfv1 = pd.DataFrame([transaction_1,transaction_2,transaction_3])
dfv1
# Out:
#        Name Item Purchased   Cost
# 0     Chris       Dog Food  22.50
# 1  Jeremiah       Cucumber   0.75
# 2    Isaiah         Coffee   2.30

# %%
# We could do the same if the we combined 3 dictionaries instead of 3 series
# First let's create the dataframe without row index labels

# Transation 1: A dictionary
transaction_1 = {'Name': 'Chris',
                          'Item Purchased': 'Dog Food',
                          'Cost': 22.50}

#Transaction 2: A dictionary
transaction_2 = {'Name': 'Jeremiah',
                'Item Purchased': 'Cucumber',
                'Cost': 0.75}

# Transaction 3: v
transaction_3 = {'Name': 'Isaiah',
                          'Item Purchased': 'Coffee',
                          'Cost': 2.30}
dfv1 = pd.DataFrame([transaction_1,transaction_2,transaction_3])
dfv1
# Out:
#     Cost Item Purchased      Name
# 0  22.50       Dog Food     Chris
# 1   0.75       Cucumber  Jeremiah
# 2   2.30         Coffee    Isaiah

# %%
# Now let's try add indexes to our rows
dfv = pd.DataFrame([transaction_1,transaction_2,transaction_3], index = ['Store 1', 'Store 2', 'Store 3'])
dfv
# Out:
#           Cost Item Purchased      Name
# Store 1  22.50       Dog Food     Chris
# Store 2   0.75       Cucumber  Jeremiah
# Store 3   2.30         Coffee    Isaiah

# %%
# What if we have a data value of a different type from the rest of the column (e.g. Cost: 'Hello!') 
# What if we were missing a value for one column in one of our dicitonaries and had a value no one else had?
# Transation 1: A dictionary
transaction_1 = {'Name': 'Chris',
                          'Item Purchased': 'Dog Food',
                          'Cost': 22.50}

#Transaction 2: A dictionary
transaction_2 = {'Name': 'Jeremiah',
                'Item Purchased': 'Cucumber',
                'Cost': 0.75}

# Transaction 3: A dictionary
transaction_3 = {'Name': 'Isaiah',
                          'Item Purchased': 'Coffee',
                          'Cost': 2.30}
# Transaction 4: A dictionary
transaction_4 = pd.Series({'Name': 'Hermione', 
                           'Hair Color':'Brown', 
                           'Cost': 'Hello!'})

dfv2 = pd.DataFrame([transaction_1,transaction_2,transaction_3,transaction_4], index = ['Store 1', 'Store 2', 'Store 3','Store 4'])
dfv2
# Out:
#            Cost Hair Color Item Purchased      Name
# Store 1    22.5        NaN       Dog Food     Chris
# Store 2    0.75        NaN       Cucumber  Jeremiah
# Store 3     2.3        NaN         Coffee    Isaiah
# Store 4  Hello!      Brown            NaN  Hermione

# %% [markdown]
# ## Querying DataFrames

# %%
# The square brackets only reference COLUMN NAMES
dfv2['Cost']
# Out:
# Store 1      22.5
# Store 2      0.75
# Store 3       2.3
# Store 4    Hello!
# Name: Cost, dtype: object

# %%
#Use loc and iloc to get rows
dfv2.iloc[1]
# Out:
# Cost                  0.75
# Hair Color             NaN
# Item Purchased    Cucumber
# Name              Jeremiah
# Name: Store 2, dtype: object

# %%
#Use loc and iloc to get rows
dfv2.loc['Store 1']
# Out:
# Cost                  22.5
# Hair Color             NaN
# Item Purchased    Dog Food
# Name                 Chris
# Name: Store 1, dtype: object

# %%
#The result of [], .loc[] and .iloc[] is a SERIES
print(type(dfv2['Cost']))
print(type(dfv2.iloc[1]))
print(type(dfv2.loc['Store 1']))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
b = dfv2.loc['Store 3']['Name'] # Problematic
b
# Out:
# 'Isaiah'

# %%
#  Chaining such as dfv.loc['Store 3']['Name'] is best AVOIDED
# CHaining causes Pandas to return a COPY of the dataframe instead of a VIEW of it.
# For selecting data, this may just be slow
# HOWEVER for CHANGING data chaning a column may cause issues

# Here is a better way
dfv2.loc[:,['Name','Cost']] # Returns ALL ROWS and the columns in the list (['Name','Cost'])
# Out:
#              Name    Cost
# Store 1     Chris    22.5
# Store 2  Jeremiah    0.75
# Store 3    Isaiah     2.3
# Store 4  Hermione  Hello!

# %%
dfv2.loc['Store 2', ['Name','Item Purchased']]
# Out:
# Name              Jeremiah
# Item Purchased    Cucumber
# Name: Store 2, dtype: object

# %% [markdown]
# ## Dropping DataFrame Rows and Columns

# %%
# THe line below DOES NOT remove Store 1. It returns a COPY of the datafram without Store 1.
# In other words this is NOT an implace operation
dfv.drop('Store 1')
# Out:
#            Cost Hair Color Item Purchased      Name
# Store 2    0.75        NaN       Cucumber  Jeremiah
# Store 3     2.3        NaN         Coffee    Isaiah
# Store 4  Hello!      Brown            NaN  Hermione

# %%
dfv # SEE? # We have to assign this copy to a variable for it to save
# Out:
#            Cost Hair Color Item Purchased      Name
# Store 1    22.5        NaN       Dog Food     Chris
# Store 2    0.75        NaN       Cucumber  Jeremiah
# Store 3     2.3        NaN         Coffee    Isaiah
# Store 4  Hello!      Brown            NaN  Hermione

# %%
# Deleting a column, axis = 1 means we are referring to a column
dfv.drop('Cost', axis=1)
# Out:
#         Hair Color Item Purchased      Name
# Store 1        NaN       Dog Food     Chris
# Store 2        NaN       Cucumber  Jeremiah
# Store 3        NaN         Coffee    Isaiah
# Store 4      Brown            NaN  Hermione

# %%
test = pd.DataFrame([{'Item':'Pack','Category':'Pack','Quantity':1,'Weight':33},
                    {'Item':'Tent','Category':'Shelter','Quantity':1,'Weight':80},
                    {'Item':'Sleeping Pad','Category':'Sleep','Quantity':0,'Weight':27},
                    {'Item':'Sleeping Pad','Category':'Sleep','Quantity':0,'Weight':11}])
test
# Out:
#   Category          Item  Quantity  Weight
# 0     Pack          Pack         1      33
# 1  Shelter          Tent         1      80
# 2    Sleep  Sleeping Pad         0      27
# 3    Sleep  Sleeping Pad         0      11

# %%
#Set the item column as the index
test.set_index('Item', inplace = True)
test
# Out:
#              Category  Quantity  Weight
# Item
# Pack             Pack         1      33
# Tent          Shelter         1      80
# Sleeping Pad    Sleep         0      27
# Sleeping Pad    Sleep         0      11

# %%
# Let's say we want to drop all rows with a 0 quantity
a = test[test['Quantity']==0]
a
# Out:
#              Category  Quantity  Weight
# Item
# Sleeping Pad    Sleep         0      27
# Sleeping Pad    Sleep         0      11

# %%
a.index
# Out:
# Index(['Sleeping Pad', 'Sleeping Pad'], dtype='object', name='Item')

# %%
# Delete a column
# To permanently delete a row or column INPLACE we can use the del operator
dfvcopy = dfv.copy() # Remember, we want to use .copy(), otherwise dfvcopy will be a reference to dfv. Changes we 
del dfvcopy['Name']
dfvcopy
# Out:
#            Cost Hair Color Item Purchased
# Store 1    22.5        NaN       Dog Food
# Store 2    0.75        NaN       Cucumber
# Store 3     2.3        NaN         Coffee
# Store 4  Hello!      Brown            NaN

# %%
# Delete entire DataFrame
del dfvcopy

# %% [markdown]
# ## Add a Column to a DataFrame

# %%
dfv10 = dfv.copy()
dfv10
# Out:
#            Cost Hair Color Item Purchased      Name
# Store 1    22.5        NaN       Dog Food     Chris
# Store 2    0.75        NaN       Cucumber  Jeremiah
# Store 3     2.3        NaN         Coffee    Isaiah
# Store 4  Hello!      Brown            NaN  Hermione

# %%
dfv10['Last Name'] = ['Chu','Huang','Ali','Leols']
dfv10
# Out:
#            Cost Hair Color Item Purchased      Name Last Name
# Store 1    22.5        NaN       Dog Food     Chris       Chu
# Store 2    0.75        NaN       Cucumber  Jeremiah     Huang
# Store 3     2.3        NaN         Coffee    Isaiah       Ali
# Store 4  Hello!      Brown            NaN  Hermione     Leols

# %% [markdown]
# ## Reading in CSV Files to DataFrames

# %%
olympics = pd.read_excel('Data/olympics.xlsx', skiprows = 1, index_col=1)
olympics.head()
# Out:
#                          Unnamed: 0  № Summer  01 !  02 !  03 !  Total  \
# Afghanistan (AFG)               NaN        13     0     0     2      2
# Algeria (ALG)                   NaN        12     5     2     8     15
# Argentina (ARG)                 NaN        23    18    24    28     70
# Armenia (ARM)                   NaN         5     1     2     9     12
# Australasia (ANZ) [ANZ]         NaN         2     3     4     5     12
#
#                          № Winter  01 !.1  02 !.1  03 !.1  Total.1  № Games  \
# Afghanistan (AFG)               0       0       0       0        0       13
# Algeria (ALG)                   3       0       0       0        0       15
# Argentina (ARG)                18       0       0       0        0       41
# Armenia (ARM)                   6       0       0       0        0       11
# Australasia (ANZ) [ANZ]         0       0       0       0        0        2
#
#                          01 !.2  02 !.2  03 !.2  Combined total
# Afghanistan (AFG)             0       0       2               2
# Algeria (ALG)                 5       2       8              15
# Argentina (ARG)              18      24      28              70
# Armenia (ARM)                 1       2       9              12
# Australasia (ANZ) [ANZ]       3       4       5              12

# %%
colnames = olympics.columns
print(colnames)
# Out:
# Index(['Unnamed: 0', '№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter',
#        '01 !.1', '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2',
#        '03 !.2', 'Combined total'],
#       dtype='object')

# %%
# Remove first column 'Unnamed: 0'
olympics.drop(colnames[0],axis=1, inplace = True) # Inplace changes the actual DataFrame permanently
olympics.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# Afghanistan (AFG)             2               2
# Algeria (ALG)                 8              15
# Argentina (ARG)              28              70
# Armenia (ARM)                 9              12
# Australasia (ANZ) [ANZ]       5              12

# %% [markdown]
# ## Rename a Column

# %%
olympics.rename(columns = {'01 !': 'Num 1','02 !': 'Num 2','03 !': 'Num 3'}, inplace = True)
olympics.head()
# Out:
#                          № Summer  Num 1  Num 2  Num 3  Total  № Winter  \
# Afghanistan (AFG)              13      0      0      2      2         0
# Algeria (ALG)                  12      5      2      8     15         3
# Argentina (ARG)                23     18     24     28     70        18
# Armenia (ARM)                   5      1      2      9     12         6
# Australasia (ANZ) [ANZ]         2      3      4      5     12         0
#
#                          01 !.1  02 !.1  03 !.1  Total.1  № Games  01 !.2  \
# Afghanistan (AFG)             0       0       0        0       13       0
# Algeria (ALG)                 0       0       0        0       15       5
# Argentina (ARG)               0       0       0        0       41      18
# Armenia (ARM)                 0       0       0        0       11       1
# Australasia (ANZ) [ANZ]       0       0       0        0        2       3
#
#                          02 !.2  03 !.2  Combined total
# Afghanistan (AFG)             0       2               2
# Algeria (ALG)                 2       8              15
# Argentina (ARG)              24      28              70
# Armenia (ARM)                 2       9              12
# Australasia (ANZ) [ANZ]       4       5              12

# %%
olympics.rename(columns={'02 !.1':'Gold', '03 !.1':'BLEH'}, inplace = True)
olympics.head()
# Out:
#                          № Summer  Num 1  Num 2  Num 3  Total  № Winter  \
# Afghanistan (AFG)              13      0      0      2      2         0
# Algeria (ALG)                  12      5      2      8     15         3
# Argentina (ARG)                23     18     24     28     70        18
# Armenia (ARM)                   5      1      2      9     12         6
# Australasia (ANZ) [ANZ]         2      3      4      5     12         0
#
#                          01 !.1  Gold  BLEH  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0     0     0        0       13       0       0
# Algeria (ALG)                 0     0     0        0       15       5       2
# Argentina (ARG)               0     0     0        0       41      18      24
# Armenia (ARM)                 0     0     0        0       11       1       2
# Australasia (ANZ) [ANZ]       0     0     0        0        2       3       4
#
#                          03 !.2  Combined total
# Afghanistan (AFG)             2               2
# Algeria (ALG)                 8              15
# Argentina (ARG)              28              70
# Armenia (ARM)                 9              12
# Australasia (ANZ) [ANZ]       5              12

# %% [markdown]
# ## Querying DataFrames

# %%
# Let's find out which countries have at least 10 gold medals
tengold = olympics['Gold'] > 1
tengold #This has all the countries still, just with those countries with <= 10 golds marked as FALSE
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                   False
# Argentina (ARG)                                 False
# Armenia (ARM)                                   False
# Australasia (ANZ) [ANZ]                         False
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                False
# Bahamas (BAH)                                   False
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                   False
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                    False
# British West Indies (BWI) [BWI]                 False
# Bulgaria (BUL) [H]                               True
# Burundi (BDI)                                   False
# Cameroon (CMR)                                  False
# Canada (CAN)                                     True
# Chile (CHI) [I]                                 False
# China (CHN) [CHN]                                True
# Colombia (COL)                                  False
# Costa Rica (CRC)                                False
# Ivory Coast (CIV) [CIV]                         False
# Croatia (CRO)                                    True
# Cuba (CUB) [Z]                                  False
# Cyprus (CYP)                                    False
#                                                 ...
# Sri Lanka (SRI) [SRI]                           False
# Sudan (SUD)                                     False
# Suriname (SUR) [E]                              False
# Sweden (SWE) [Z]                                 True
# Switzerland (SUI)                                True
# Syria (SYR)                                     False
# Chinese Taipei (TPE) [TPE] [TPE2]               False
# Tajikistan (TJK)                                False
# Tanzania (TAN) [TAN]                            False
# Thailand (THA)                                  False
# Togo (TOG)                                      False
# Tonga (TGA)                                     False
# Trinidad and Tobago (TRI) [TRI]                 False
# Tunisia (TUN)                                   False
# Turkey (TUR)                                    False
# Uganda (UGA)                                    False
# Ukraine (UKR)                                   False
# United Arab Emirates (UAE)                      False
# United States (USA) [P] [Q] [R] [Z]              True
# Uruguay (URU)                                   False
# Uzbekistan (UZB)                                False
# Venezuela (VEN)                                 False
# Vietnam (VIE)                                   False
# Virgin Islands (ISV)                            False
# Yugoslavia (YUG) [YUG]                           True
# Independent Olympic Participants (IOP) [IOP]    False
# Zambia (ZAM) [ZAM]                              False
# Zimbabwe (ZIM) [ZIM]                            False
# Mixed team (ZZX) [ZZX]                          False
# Totals                                           True
# Name: Gold, Length: 147, dtype: bool

# %%
# The WHERE() funciton takes a BOOLEAN function, applies it to a dataframe and returns a new dataframe
only_gold = olympics.where(olympics['Gold'] > 0)
only_gold # Note that rows that do not meet the requirements specified by the Boolean funciton return NaN
# Out:
#                                               № Summer   Num 1   Num 2  \
# Afghanistan (AFG)                                  NaN     NaN     NaN
# Algeria (ALG)                                      NaN     NaN     NaN
# Argentina (ARG)                                    NaN     NaN     NaN
# Armenia (ARM)                                      NaN     NaN     NaN
# Australasia (ANZ) [ANZ]                            NaN     NaN     NaN
# Australia (AUS) [AUS] [Z]                         25.0   139.0   152.0
# Austria (AUT)                                     26.0    18.0    33.0
# Azerbaijan (AZE)                                   NaN     NaN     NaN
# Bahamas (BAH)                                      NaN     NaN     NaN
# Bahrain (BRN)                                      NaN     NaN     NaN
# Barbados (BAR) [BAR]                               NaN     NaN     NaN
# Belarus (BLR)                                      5.0    12.0    24.0
# Belgium (BEL)                                     25.0    37.0    52.0
# Bermuda (BER)                                      NaN     NaN     NaN
# Bohemia (BOH) [BOH] [Z]                            NaN     NaN     NaN
# Botswana (BOT)                                     NaN     NaN     NaN
# Brazil (BRA)                                       NaN     NaN     NaN
# British West Indies (BWI) [BWI]                    NaN     NaN     NaN
# Bulgaria (BUL) [H]                                19.0    51.0    85.0
# Burundi (BDI)                                      NaN     NaN     NaN
# Cameroon (CMR)                                     NaN     NaN     NaN
# Canada (CAN)                                      25.0    59.0    99.0
# Chile (CHI) [I]                                    NaN     NaN     NaN
# China (CHN) [CHN]                                  9.0   201.0   146.0
# Colombia (COL)                                     NaN     NaN     NaN
# Costa Rica (CRC)                                   NaN     NaN     NaN
# Ivory Coast (CIV) [CIV]                            NaN     NaN     NaN
# Croatia (CRO)                                      6.0     6.0     7.0
# Cuba (CUB) [Z]                                     NaN     NaN     NaN
# Cyprus (CYP)                                       NaN     NaN     NaN
# ...                                                ...     ...     ...
# Sri Lanka (SRI) [SRI]                              NaN     NaN     NaN
# Sudan (SUD)                                        NaN     NaN     NaN
# Suriname (SUR) [E]                                 NaN     NaN     NaN
# Sweden (SWE) [Z]                                  26.0   143.0   164.0
# Switzerland (SUI)                                 27.0    47.0    73.0
# Syria (SYR)                                        NaN     NaN     NaN
# Chinese Taipei (TPE) [TPE] [TPE2]                  NaN     NaN     NaN
# Tajikistan (TJK)                                   NaN     NaN     NaN
# Tanzania (TAN) [TAN]                               NaN     NaN     NaN
# Thailand (THA)                                     NaN     NaN     NaN
# Togo (TOG)                                         NaN     NaN     NaN
# Tonga (TGA)                                        NaN     NaN     NaN
# Trinidad and Tobago (TRI) [TRI]                    NaN     NaN     NaN
# Tunisia (TUN)                                      NaN     NaN     NaN
# Turkey (TUR)                                       NaN     NaN     NaN
# Uganda (UGA)                                       NaN     NaN     NaN
# Ukraine (UKR)                                      5.0    33.0    27.0
# United Arab Emirates (UAE)                         NaN     NaN     NaN
# United States (USA) [P] [Q] [R] [Z]               26.0   976.0   757.0
# Uruguay (URU)                                      NaN     NaN     NaN
# Uzbekistan (UZB)                                   NaN     NaN     NaN
# Venezuela (VEN)                                    NaN     NaN     NaN
# Vietnam (VIE)                                      NaN     NaN     NaN
# Virgin Islands (ISV)                               NaN     NaN     NaN
# Yugoslavia (YUG) [YUG]                            16.0    26.0    29.0
# Independent Olympic Participants (IOP) [IOP]       NaN     NaN     NaN
# Zambia (ZAM) [ZAM]                                 NaN     NaN     NaN
# Zimbabwe (ZIM) [ZIM]                               NaN     NaN     NaN
# Mixed team (ZZX) [ZZX]                             NaN     NaN     NaN
# Totals                                            27.0  4809.0  4775.0
#
#                                                Num 3    Total  № Winter  \
# Afghanistan (AFG)                                NaN      NaN       NaN
# Algeria (ALG)                                    NaN      NaN       NaN
# Argentina (ARG)                                  NaN      NaN       NaN
# Armenia (ARM)                                    NaN      NaN       NaN
# Australasia (ANZ) [ANZ]                          NaN      NaN       NaN
# Australia (AUS) [AUS] [Z]                      177.0    468.0      18.0
# Austria (AUT)                                   35.0     86.0      22.0
# Azerbaijan (AZE)                                 NaN      NaN       NaN
# Bahamas (BAH)                                    NaN      NaN       NaN
# Bahrain (BRN)                                    NaN      NaN       NaN
# Barbados (BAR) [BAR]                             NaN      NaN       NaN
# Belarus (BLR)                                   39.0     75.0       6.0
# Belgium (BEL)                                   53.0    142.0      20.0
# Bermuda (BER)                                    NaN      NaN       NaN
# Bohemia (BOH) [BOH] [Z]                          NaN      NaN       NaN
# Botswana (BOT)                                   NaN      NaN       NaN
# Brazil (BRA)                                     NaN      NaN       NaN
# British West Indies (BWI) [BWI]                  NaN      NaN       NaN
# Bulgaria (BUL) [H]                              78.0    214.0      19.0
# Burundi (BDI)                                    NaN      NaN       NaN
# Cameroon (CMR)                                   NaN      NaN       NaN
# Canada (CAN)                                   121.0    279.0      22.0
# Chile (CHI) [I]                                  NaN      NaN       NaN
# China (CHN) [CHN]                              126.0    473.0      10.0
# Colombia (COL)                                   NaN      NaN       NaN
# Costa Rica (CRC)                                 NaN      NaN       NaN
# Ivory Coast (CIV) [CIV]                          NaN      NaN       NaN
# Croatia (CRO)                                   10.0     23.0       7.0
# Cuba (CUB) [Z]                                   NaN      NaN       NaN
# Cyprus (CYP)                                     NaN      NaN       NaN
# ...                                              ...      ...       ...
# Sri Lanka (SRI) [SRI]                            NaN      NaN       NaN
# Sudan (SUD)                                      NaN      NaN       NaN
# Suriname (SUR) [E]                               NaN      NaN       NaN
# Sweden (SWE) [Z]                               176.0    483.0      22.0
# Switzerland (SUI)                               65.0    185.0      22.0
# Syria (SYR)                                      NaN      NaN       NaN
# Chinese Taipei (TPE) [TPE] [TPE2]                NaN      NaN       NaN
# Tajikistan (TJK)                                 NaN      NaN       NaN
# Tanzania (TAN) [TAN]                             NaN      NaN       NaN
# Thailand (THA)                                   NaN      NaN       NaN
# Togo (TOG)                                       NaN      NaN       NaN
# Tonga (TGA)                                      NaN      NaN       NaN
# Trinidad and Tobago (TRI) [TRI]                  NaN      NaN       NaN
# Tunisia (TUN)                                    NaN      NaN       NaN
# Turkey (TUR)                                     NaN      NaN       NaN
# Uganda (UGA)                                     NaN      NaN       NaN
# Ukraine (UKR)                                   55.0    115.0       6.0
# United Arab Emirates (UAE)                       NaN      NaN       NaN
# United States (USA) [P] [Q] [R] [Z]            666.0   2399.0      22.0
# Uruguay (URU)                                    NaN      NaN       NaN
# Uzbekistan (UZB)                                 NaN      NaN       NaN
# Venezuela (VEN)                                  NaN      NaN       NaN
# Vietnam (VIE)                                    NaN      NaN       NaN
# Virgin Islands (ISV)                             NaN      NaN       NaN
# Yugoslavia (YUG) [YUG]                          28.0     83.0      14.0
# Independent Olympic Participants (IOP) [IOP]     NaN      NaN       NaN
# Zambia (ZAM) [ZAM]                               NaN      NaN       NaN
# Zimbabwe (ZIM) [ZIM]                             NaN      NaN       NaN
# Mixed team (ZZX) [ZZX]                           NaN      NaN       NaN
# Totals                                        5130.0  14714.0      22.0
#
#                                               01 !.1   Gold   BLEH  Total.1  \
# Afghanistan (AFG)                                NaN    NaN    NaN      NaN
# Algeria (ALG)                                    NaN    NaN    NaN      NaN
# Argentina (ARG)                                  NaN    NaN    NaN      NaN
# Armenia (ARM)                                    NaN    NaN    NaN      NaN
# Australasia (ANZ) [ANZ]                          NaN    NaN    NaN      NaN
# Australia (AUS) [AUS] [Z]                        5.0    3.0    4.0     12.0
# Austria (AUT)                                   59.0   78.0   81.0    218.0
# Azerbaijan (AZE)                                 NaN    NaN    NaN      NaN
# Bahamas (BAH)                                    NaN    NaN    NaN      NaN
# Bahrain (BRN)                                    NaN    NaN    NaN      NaN
# Barbados (BAR) [BAR]                             NaN    NaN    NaN      NaN
# Belarus (BLR)                                    6.0    4.0    5.0     15.0
# Belgium (BEL)                                    1.0    1.0    3.0      5.0
# Bermuda (BER)                                    NaN    NaN    NaN      NaN
# Bohemia (BOH) [BOH] [Z]                          NaN    NaN    NaN      NaN
# Botswana (BOT)                                   NaN    NaN    NaN      NaN
# Brazil (BRA)                                     NaN    NaN    NaN      NaN
# British West Indies (BWI) [BWI]                  NaN    NaN    NaN      NaN
# Bulgaria (BUL) [H]                               1.0    2.0    3.0      6.0
# Burundi (BDI)                                    NaN    NaN    NaN      NaN
# Cameroon (CMR)                                   NaN    NaN    NaN      NaN
# Canada (CAN)                                    62.0   56.0   52.0    170.0
# Chile (CHI) [I]                                  NaN    NaN    NaN      NaN
# China (CHN) [CHN]                               12.0   22.0   19.0     53.0
# Colombia (COL)                                   NaN    NaN    NaN      NaN
# Costa Rica (CRC)                                 NaN    NaN    NaN      NaN
# Ivory Coast (CIV) [CIV]                          NaN    NaN    NaN      NaN
# Croatia (CRO)                                    4.0    6.0    1.0     11.0
# Cuba (CUB) [Z]                                   NaN    NaN    NaN      NaN
# Cyprus (CYP)                                     NaN    NaN    NaN      NaN
# ...                                              ...    ...    ...      ...
# Sri Lanka (SRI) [SRI]                            NaN    NaN    NaN      NaN
# Sudan (SUD)                                      NaN    NaN    NaN      NaN
# Suriname (SUR) [E]                               NaN    NaN    NaN      NaN
# Sweden (SWE) [Z]                                50.0   40.0   54.0    144.0
# Switzerland (SUI)                               50.0   40.0   48.0    138.0
# Syria (SYR)                                      NaN    NaN    NaN      NaN
# Chinese Taipei (TPE) [TPE] [TPE2]                NaN    NaN    NaN      NaN
# Tajikistan (TJK)                                 NaN    NaN    NaN      NaN
# Tanzania (TAN) [TAN]                             NaN    NaN    NaN      NaN
# Thailand (THA)                                   NaN    NaN    NaN      NaN
# Togo (TOG)                                       NaN    NaN    NaN      NaN
# Tonga (TGA)                                      NaN    NaN    NaN      NaN
# Trinidad and Tobago (TRI) [TRI]                  NaN    NaN    NaN      NaN
# Tunisia (TUN)                                    NaN    NaN    NaN      NaN
# Turkey (TUR)                                     NaN    NaN    NaN      NaN
# Uganda (UGA)                                     NaN    NaN    NaN      NaN
# Ukraine (UKR)                                    2.0    1.0    4.0      7.0
# United Arab Emirates (UAE)                       NaN    NaN    NaN      NaN
# United States (USA) [P] [Q] [R] [Z]             96.0  102.0   84.0    282.0
# Uruguay (URU)                                    NaN    NaN    NaN      NaN
# Uzbekistan (UZB)                                 NaN    NaN    NaN      NaN
# Venezuela (VEN)                                  NaN    NaN    NaN      NaN
# Vietnam (VIE)                                    NaN    NaN    NaN      NaN
# Virgin Islands (ISV)                             NaN    NaN    NaN      NaN
# Yugoslavia (YUG) [YUG]                           0.0    3.0    1.0      4.0
# Independent Olympic Participants (IOP) [IOP]     NaN    NaN    NaN      NaN
# Zambia (ZAM) [ZAM]                               NaN    NaN    NaN      NaN
# Zimbabwe (ZIM) [ZIM]                             NaN    NaN    NaN      NaN
# Mixed team (ZZX) [ZZX]                           NaN    NaN    NaN      NaN
# Totals                                         959.0  958.0  948.0   2865.0
#
#                                               № Games  01 !.2  02 !.2  03 !.2  \
# Afghanistan (AFG)                                 NaN     NaN     NaN     NaN
# Algeria (ALG)                                     NaN     NaN     NaN     NaN
# Argentina (ARG)                                   NaN     NaN     NaN     NaN
# Armenia (ARM)                                     NaN     NaN     NaN     NaN
# Australasia (ANZ) [ANZ]                           NaN     NaN     NaN     NaN
# Australia (AUS) [AUS] [Z]                        43.0   144.0   155.0   181.0
# Austria (AUT)                                    48.0    77.0   111.0   116.0
# Azerbaijan (AZE)                                  NaN     NaN     NaN     NaN
# Bahamas (BAH)                                     NaN     NaN     NaN     NaN
# Bahrain (BRN)                                     NaN     NaN     NaN     NaN
# Barbados (BAR) [BAR]                              NaN     NaN     NaN     NaN
# Belarus (BLR)                                    11.0    18.0    28.0    44.0
# Belgium (BEL)                                    45.0    38.0    53.0    56.0
# Bermuda (BER)                                     NaN     NaN     NaN     NaN
# Bohemia (BOH) [BOH] [Z]                           NaN     NaN     NaN     NaN
# Botswana (BOT)                                    NaN     NaN     NaN     NaN
# Brazil (BRA)                                      NaN     NaN     NaN     NaN
# British West Indies (BWI) [BWI]                   NaN     NaN     NaN     NaN
# Bulgaria (BUL) [H]                               38.0    52.0    87.0    81.0
# Burundi (BDI)                                     NaN     NaN     NaN     NaN
# Cameroon (CMR)                                    NaN     NaN     NaN     NaN
# Canada (CAN)                                     47.0   121.0   155.0   173.0
# Chile (CHI) [I]                                   NaN     NaN     NaN     NaN
# China (CHN) [CHN]                                19.0   213.0   168.0   145.0
# Colombia (COL)                                    NaN     NaN     NaN     NaN
# Costa Rica (CRC)                                  NaN     NaN     NaN     NaN
# Ivory Coast (CIV) [CIV]                           NaN     NaN     NaN     NaN
# Croatia (CRO)                                    13.0    10.0    13.0    11.0
# Cuba (CUB) [Z]                                    NaN     NaN     NaN     NaN
# Cyprus (CYP)                                      NaN     NaN     NaN     NaN
# ...                                               ...     ...     ...     ...
# Sri Lanka (SRI) [SRI]                             NaN     NaN     NaN     NaN
# Sudan (SUD)                                       NaN     NaN     NaN     NaN
# Suriname (SUR) [E]                                NaN     NaN     NaN     NaN
# Sweden (SWE) [Z]                                 48.0   193.0   204.0   230.0
# Switzerland (SUI)                                49.0    97.0   113.0   113.0
# Syria (SYR)                                       NaN     NaN     NaN     NaN
# Chinese Taipei (TPE) [TPE] [TPE2]                 NaN     NaN     NaN     NaN
# Tajikistan (TJK)                                  NaN     NaN     NaN     NaN
# Tanzania (TAN) [TAN]                              NaN     NaN     NaN     NaN
# Thailand (THA)                                    NaN     NaN     NaN     NaN
# Togo (TOG)                                        NaN     NaN     NaN     NaN
# Tonga (TGA)                                       NaN     NaN     NaN     NaN
# Trinidad and Tobago (TRI) [TRI]                   NaN     NaN     NaN     NaN
# Tunisia (TUN)                                     NaN     NaN     NaN     NaN
# Turkey (TUR)                                      NaN     NaN     NaN     NaN
# Uganda (UGA)                                      NaN     NaN     NaN     NaN
# Ukraine (UKR)                                    11.0    35.0    28.0    59.0
# United Arab Emirates (UAE)                        NaN     NaN     NaN     NaN
# United States (USA) [P] [Q] [R] [Z]              48.0  1072.0   859.0   750.0
# Uruguay (URU)                                     NaN     NaN     NaN     NaN
# Uzbekistan (UZB)                                  NaN     NaN     NaN     NaN
# Venezuela (VEN)                                   NaN     NaN     NaN     NaN
# Vietnam (VIE)                                     NaN     NaN     NaN     NaN
# Virgin Islands (ISV)                              NaN     NaN     NaN     NaN
# Yugoslavia (YUG) [YUG]                           30.0    26.0    32.0    29.0
# Independent Olympic Participants (IOP) [IOP]      NaN     NaN     NaN     NaN
# Zambia (ZAM) [ZAM]                                NaN     NaN     NaN     NaN
# Zimbabwe (ZIM) [ZIM]                              NaN     NaN     NaN     NaN
# Mixed team (ZZX) [ZZX]                            NaN     NaN     NaN     NaN
# Totals                                           49.0  5768.0  5733.0  6078.0
#
#                                               Combined total
# Afghanistan (AFG)                                        NaN
# Algeria (ALG)                                            NaN
# Argentina (ARG)                                          NaN
# Armenia (ARM)                                            NaN
# Australasia (ANZ) [ANZ]                                  NaN
# Australia (AUS) [AUS] [Z]                              480.0
# Austria (AUT)                                          304.0
# Azerbaijan (AZE)                                         NaN
# Bahamas (BAH)                                            NaN
# Bahrain (BRN)                                            NaN
# Barbados (BAR) [BAR]                                     NaN
# Belarus (BLR)                                           90.0
# Belgium (BEL)                                          147.0
# Bermuda (BER)                                            NaN
# Bohemia (BOH) [BOH] [Z]                                  NaN
# Botswana (BOT)                                           NaN
# Brazil (BRA)                                             NaN
# British West Indies (BWI) [BWI]                          NaN
# Bulgaria (BUL) [H]                                     220.0
# Burundi (BDI)                                            NaN
# Cameroon (CMR)                                           NaN
# Canada (CAN)                                           449.0
# Chile (CHI) [I]                                          NaN
# China (CHN) [CHN]                                      526.0
# Colombia (COL)                                           NaN
# Costa Rica (CRC)                                         NaN
# Ivory Coast (CIV) [CIV]                                  NaN
# Croatia (CRO)                                           34.0
# Cuba (CUB) [Z]                                           NaN
# Cyprus (CYP)                                             NaN
# ...                                                      ...
# Sri Lanka (SRI) [SRI]                                    NaN
# Sudan (SUD)                                              NaN
# Suriname (SUR) [E]                                       NaN
# Sweden (SWE) [Z]                                       627.0
# Switzerland (SUI)                                      323.0
# Syria (SYR)                                              NaN
# Chinese Taipei (TPE) [TPE] [TPE2]                        NaN
# Tajikistan (TJK)                                         NaN
# Tanzania (TAN) [TAN]                                     NaN
# Thailand (THA)                                           NaN
# Togo (TOG)                                               NaN
# Tonga (TGA)                                              NaN
# Trinidad and Tobago (TRI) [TRI]                          NaN
# Tunisia (TUN)                                            NaN
# Turkey (TUR)                                             NaN
# Uganda (UGA)                                             NaN
# Ukraine (UKR)                                          122.0
# United Arab Emirates (UAE)                               NaN
# United States (USA) [P] [Q] [R] [Z]                   2681.0
# Uruguay (URU)                                            NaN
# Uzbekistan (UZB)                                         NaN
# Venezuela (VEN)                                          NaN
# Vietnam (VIE)                                            NaN
# Virgin Islands (ISV)                                     NaN
# Yugoslavia (YUG) [YUG]                                  87.0
# Independent Olympic Participants (IOP) [IOP]             NaN
# Zambia (ZAM) [ZAM]                                       NaN
# Zimbabwe (ZIM) [ZIM]                                     NaN
# Mixed team (ZZX) [ZZX]                                   NaN
# Totals                                               17579.0
#
# [147 rows x 15 columns]

# %%
# How tp remove rows that are ALL NaN
# The dropna() method from the dataframe class can remove rows/cols where any or all of the data are missing
# DataFrame.dropna(axis=0, how='any' or 'all' , thresh=None, subset=None, inplace=False)
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html

only_gold.dropna(axis=0, how='all', inplace = True)
only_gold
# Out:
#                                      № Summer   Num 1   Num 2   Num 3  \
# Australia (AUS) [AUS] [Z]                25.0   139.0   152.0   177.0
# Austria (AUT)                            26.0    18.0    33.0    35.0
# Belarus (BLR)                             5.0    12.0    24.0    39.0
# Belgium (BEL)                            25.0    37.0    52.0    53.0
# Bulgaria (BUL) [H]                       19.0    51.0    85.0    78.0
# Canada (CAN)                             25.0    59.0    99.0   121.0
# China (CHN) [CHN]                         9.0   201.0   146.0   126.0
# Croatia (CRO)                             6.0     6.0     7.0    10.0
# Czech Republic (CZE) [CZE]                5.0    14.0    15.0    15.0
# Czechoslovakia (TCH) [TCH]               16.0    49.0    49.0    45.0
# Denmark (DEN) [Z]                        26.0    43.0    68.0    68.0
# Estonia (EST)                            11.0     9.0     9.0    15.0
# Finland (FIN)                            24.0   101.0    84.0   117.0
# France (FRA) [O] [P] [Z]                 27.0   202.0   223.0   246.0
# Germany (GER) [GER] [Z]                  15.0   174.0   182.0   217.0
# United Team of Germany (EUA) [EUA]        3.0    28.0    54.0    36.0
# East Germany (GDR) [GDR]                  5.0   153.0   129.0   127.0
# West Germany (FRG) [FRG]                  5.0    56.0    67.0    81.0
# Great Britain (GBR) [GBR] [Z]            27.0   236.0   272.0   272.0
# Hungary (HUN)                            25.0   167.0   144.0   165.0
# Italy (ITA) [M] [S]                      26.0   198.0   166.0   185.0
# Japan (JPN)                              21.0   130.0   126.0   142.0
# Kazakhstan (KAZ)                          5.0    16.0    17.0    19.0
# North Korea (PRK)                         9.0    14.0    12.0    21.0
# South Korea (KOR)                        16.0    81.0    82.0    80.0
# Latvia (LAT)                             10.0     3.0    11.0     5.0
# Liechtenstein (LIE)                      16.0     0.0     0.0     0.0
# Luxembourg (LUX) [O]                     22.0     1.0     1.0     0.0
# Netherlands (NED) [Z]                    25.0    77.0    85.0   104.0
# New Zealand (NZL) [NZL]                  22.0    42.0    18.0    39.0
# Norway (NOR) [Q]                         24.0    56.0    49.0    43.0
# Poland (POL)                             20.0    64.0    82.0   125.0
# Russia (RUS) [RUS]                        5.0   132.0   121.0   142.0
# Soviet Union (URS) [URS]                  9.0   395.0   319.0   296.0
# Unified Team (EUN) [EUN]                  1.0    45.0    38.0    29.0
# Slovakia (SVK) [SVK]                      5.0     7.0     9.0     8.0
# Slovenia (SLO)                            6.0     4.0     6.0     9.0
# Sweden (SWE) [Z]                         26.0   143.0   164.0   176.0
# Switzerland (SUI)                        27.0    47.0    73.0    65.0
# Ukraine (UKR)                             5.0    33.0    27.0    55.0
# United States (USA) [P] [Q] [R] [Z]      26.0   976.0   757.0   666.0
# Yugoslavia (YUG) [YUG]                   16.0    26.0    29.0    28.0
# Totals                                   27.0  4809.0  4775.0  5130.0
#
#                                        Total  № Winter  01 !.1   Gold   BLEH  \
# Australia (AUS) [AUS] [Z]              468.0      18.0     5.0    3.0    4.0
# Austria (AUT)                           86.0      22.0    59.0   78.0   81.0
# Belarus (BLR)                           75.0       6.0     6.0    4.0    5.0
# Belgium (BEL)                          142.0      20.0     1.0    1.0    3.0
# Bulgaria (BUL) [H]                     214.0      19.0     1.0    2.0    3.0
# Canada (CAN)                           279.0      22.0    62.0   56.0   52.0
# China (CHN) [CHN]                      473.0      10.0    12.0   22.0   19.0
# Croatia (CRO)                           23.0       7.0     4.0    6.0    1.0
# Czech Republic (CZE) [CZE]              44.0       6.0     7.0    9.0    8.0
# Czechoslovakia (TCH) [TCH]             143.0      16.0     2.0    8.0   15.0
# Denmark (DEN) [Z]                      179.0      13.0     0.0    1.0    0.0
# Estonia (EST)                           33.0       9.0     4.0    2.0    1.0
# Finland (FIN)                          302.0      22.0    42.0   62.0   57.0
# France (FRA) [O] [P] [Z]               671.0      22.0    31.0   31.0   47.0
# Germany (GER) [GER] [Z]                573.0      11.0    78.0   78.0   53.0
# United Team of Germany (EUA) [EUA]     118.0       3.0     8.0    6.0    5.0
# East Germany (GDR) [GDR]               409.0       6.0    39.0   36.0   35.0
# West Germany (FRG) [FRG]               204.0       6.0    11.0   15.0   13.0
# Great Britain (GBR) [GBR] [Z]          780.0      22.0    10.0    4.0   12.0
# Hungary (HUN)                          476.0      22.0     0.0    2.0    4.0
# Italy (ITA) [M] [S]                    549.0      22.0    37.0   34.0   43.0
# Japan (JPN)                            398.0      20.0    10.0   17.0   18.0
# Kazakhstan (KAZ)                        52.0       6.0     1.0    3.0    3.0
# North Korea (PRK)                       47.0       8.0     0.0    1.0    1.0
# South Korea (KOR)                      243.0      17.0    26.0   17.0   10.0
# Latvia (LAT)                            19.0      10.0     0.0    4.0    3.0
# Liechtenstein (LIE)                      0.0      18.0     2.0    2.0    5.0
# Luxembourg (LUX) [O]                     2.0       8.0     0.0    2.0    0.0
# Netherlands (NED) [Z]                  266.0      20.0    37.0   38.0   35.0
# New Zealand (NZL) [NZL]                 99.0      15.0     0.0    1.0    0.0
# Norway (NOR) [Q]                       148.0      22.0   118.0  111.0  100.0
# Poland (POL)                           271.0      22.0     6.0    7.0    7.0
# Russia (RUS) [RUS]                     395.0       6.0    49.0   40.0   35.0
# Soviet Union (URS) [URS]              1010.0       9.0    78.0   57.0   59.0
# Unified Team (EUN) [EUN]               112.0       1.0     9.0    6.0    8.0
# Slovakia (SVK) [SVK]                    24.0       6.0     2.0    2.0    1.0
# Slovenia (SLO)                          19.0       7.0     2.0    4.0    9.0
# Sweden (SWE) [Z]                       483.0      22.0    50.0   40.0   54.0
# Switzerland (SUI)                      185.0      22.0    50.0   40.0   48.0
# Ukraine (UKR)                          115.0       6.0     2.0    1.0    4.0
# United States (USA) [P] [Q] [R] [Z]   2399.0      22.0    96.0  102.0   84.0
# Yugoslavia (YUG) [YUG]                  83.0      14.0     0.0    3.0    1.0
# Totals                               14714.0      22.0   959.0  958.0  948.0
#
#                                      Total.1  № Games  01 !.2  02 !.2  03 !.2  \
# Australia (AUS) [AUS] [Z]               12.0     43.0   144.0   155.0   181.0
# Austria (AUT)                          218.0     48.0    77.0   111.0   116.0
# Belarus (BLR)                           15.0     11.0    18.0    28.0    44.0
# Belgium (BEL)                            5.0     45.0    38.0    53.0    56.0
# Bulgaria (BUL) [H]                       6.0     38.0    52.0    87.0    81.0
# Canada (CAN)                           170.0     47.0   121.0   155.0   173.0
# China (CHN) [CHN]                       53.0     19.0   213.0   168.0   145.0
# Croatia (CRO)                           11.0     13.0    10.0    13.0    11.0
# Czech Republic (CZE) [CZE]              24.0     11.0    21.0    24.0    23.0
# Czechoslovakia (TCH) [TCH]              25.0     32.0    51.0    57.0    60.0
# Denmark (DEN) [Z]                        1.0     39.0    43.0    69.0    68.0
# Estonia (EST)                            7.0     20.0    13.0    11.0    16.0
# Finland (FIN)                          161.0     46.0   143.0   146.0   174.0
# France (FRA) [O] [P] [Z]               109.0     49.0   233.0   254.0   293.0
# Germany (GER) [GER] [Z]                209.0     26.0   252.0   260.0   270.0
# United Team of Germany (EUA) [EUA]      19.0      6.0    36.0    60.0    41.0
# East Germany (GDR) [GDR]               110.0     11.0   192.0   165.0   162.0
# West Germany (FRG) [FRG]                39.0     11.0    67.0    82.0    94.0
# Great Britain (GBR) [GBR] [Z]           26.0     49.0   246.0   276.0   284.0
# Hungary (HUN)                            6.0     47.0   167.0   146.0   169.0
# Italy (ITA) [M] [S]                    114.0     48.0   235.0   200.0   228.0
# Japan (JPN)                             45.0     41.0   140.0   143.0   160.0
# Kazakhstan (KAZ)                         7.0     11.0    17.0    20.0    22.0
# North Korea (PRK)                        2.0     17.0    14.0    13.0    22.0
# South Korea (KOR)                       53.0     33.0   107.0    99.0    90.0
# Latvia (LAT)                             7.0     20.0     3.0    15.0     8.0
# Liechtenstein (LIE)                      9.0     34.0     2.0     2.0     5.0
# Luxembourg (LUX) [O]                     2.0     30.0     1.0     3.0     0.0
# Netherlands (NED) [Z]                  110.0     45.0   114.0   123.0   139.0
# New Zealand (NZL) [NZL]                  1.0     37.0    42.0    19.0    39.0
# Norway (NOR) [Q]                       329.0     46.0   174.0   160.0   143.0
# Poland (POL)                            20.0     42.0    70.0    89.0   132.0
# Russia (RUS) [RUS]                     124.0     11.0   181.0   161.0   177.0
# Soviet Union (URS) [URS]               194.0     18.0   473.0   376.0   355.0
# Unified Team (EUN) [EUN]                23.0      2.0    54.0    44.0    37.0
# Slovakia (SVK) [SVK]                     5.0     11.0     9.0    11.0     9.0
# Slovenia (SLO)                          15.0     13.0     6.0    10.0    18.0
# Sweden (SWE) [Z]                       144.0     48.0   193.0   204.0   230.0
# Switzerland (SUI)                      138.0     49.0    97.0   113.0   113.0
# Ukraine (UKR)                            7.0     11.0    35.0    28.0    59.0
# United States (USA) [P] [Q] [R] [Z]    282.0     48.0  1072.0   859.0   750.0
# Yugoslavia (YUG) [YUG]                   4.0     30.0    26.0    32.0    29.0
# Totals                                2865.0     49.0  5768.0  5733.0  6078.0
#
#                                      Combined total
# Australia (AUS) [AUS] [Z]                     480.0
# Austria (AUT)                                 304.0
# Belarus (BLR)                                  90.0
# Belgium (BEL)                                 147.0
# Bulgaria (BUL) [H]                            220.0
# Canada (CAN)                                  449.0
# China (CHN) [CHN]                             526.0
# Croatia (CRO)                                  34.0
# Czech Republic (CZE) [CZE]                     68.0
# Czechoslovakia (TCH) [TCH]                    168.0
# Denmark (DEN) [Z]                             180.0
# Estonia (EST)                                  40.0
# Finland (FIN)                                 463.0
# France (FRA) [O] [P] [Z]                      780.0
# Germany (GER) [GER] [Z]                       782.0
# United Team of Germany (EUA) [EUA]            137.0
# East Germany (GDR) [GDR]                      519.0
# West Germany (FRG) [FRG]                      243.0
# Great Britain (GBR) [GBR] [Z]                 806.0
# Hungary (HUN)                                 482.0
# Italy (ITA) [M] [S]                           663.0
# Japan (JPN)                                   443.0
# Kazakhstan (KAZ)                               59.0
# North Korea (PRK)                              49.0
# South Korea (KOR)                             296.0
# Latvia (LAT)                                   26.0
# Liechtenstein (LIE)                             9.0
# Luxembourg (LUX) [O]                            4.0
# Netherlands (NED) [Z]                         376.0
# New Zealand (NZL) [NZL]                       100.0
# Norway (NOR) [Q]                              477.0
# Poland (POL)                                  291.0
# Russia (RUS) [RUS]                            519.0
# Soviet Union (URS) [URS]                     1204.0
# Unified Team (EUN) [EUN]                      135.0
# Slovakia (SVK) [SVK]                           29.0
# Slovenia (SLO)                                 34.0
# Sweden (SWE) [Z]                              627.0
# Switzerland (SUI)                             323.0
# Ukraine (UKR)                                 122.0
# United States (USA) [P] [Q] [R] [Z]          2681.0
# Yugoslavia (YUG) [YUG]                         87.0
# Totals                                      17579.0

# %%
# When you input the boolean statement into the square brackets instead of using the where() dataframe method,
# you do not get the NaN values, just a dataframe of rows that return true for the specified boolean statement.
olympics[(olympics['Gold'] > 1) & (olympics['BLEH'] > 10)] # EACH BOOLEAN MASK MUST BE WRAPPED IN PARENTHESES
# Out:
#                                      № Summer  Num 1  Num 2  Num 3  Total  \
# Austria (AUT)                              26     18     33     35     86
# Canada (CAN)                               25     59     99    121    279
# China (CHN) [CHN]                           9    201    146    126    473
# Czechoslovakia (TCH) [TCH]                 16     49     49     45    143
# Finland (FIN)                              24    101     84    117    302
# France (FRA) [O] [P] [Z]                   27    202    223    246    671
# Germany (GER) [GER] [Z]                    15    174    182    217    573
# East Germany (GDR) [GDR]                    5    153    129    127    409
# West Germany (FRG) [FRG]                    5     56     67     81    204
# Great Britain (GBR) [GBR] [Z]              27    236    272    272    780
# Italy (ITA) [M] [S]                        26    198    166    185    549
# Japan (JPN)                                21    130    126    142    398
# Netherlands (NED) [Z]                      25     77     85    104    266
# Norway (NOR) [Q]                           24     56     49     43    148
# Russia (RUS) [RUS]                          5    132    121    142    395
# Soviet Union (URS) [URS]                    9    395    319    296   1010
# Sweden (SWE) [Z]                           26    143    164    176    483
# Switzerland (SUI)                          27     47     73     65    185
# United States (USA) [P] [Q] [R] [Z]        26    976    757    666   2399
# Totals                                     27   4809   4775   5130  14714
#
#                                      № Winter  01 !.1  Gold  BLEH  Total.1  \
# Austria (AUT)                              22      59    78    81      218
# Canada (CAN)                               22      62    56    52      170
# China (CHN) [CHN]                          10      12    22    19       53
# Czechoslovakia (TCH) [TCH]                 16       2     8    15       25
# Finland (FIN)                              22      42    62    57      161
# France (FRA) [O] [P] [Z]                   22      31    31    47      109
# Germany (GER) [GER] [Z]                    11      78    78    53      209
# East Germany (GDR) [GDR]                    6      39    36    35      110
# West Germany (FRG) [FRG]                    6      11    15    13       39
# Great Britain (GBR) [GBR] [Z]              22      10     4    12       26
# Italy (ITA) [M] [S]                        22      37    34    43      114
# Japan (JPN)                                20      10    17    18       45
# Netherlands (NED) [Z]                      20      37    38    35      110
# Norway (NOR) [Q]                           22     118   111   100      329
# Russia (RUS) [RUS]                          6      49    40    35      124
# Soviet Union (URS) [URS]                    9      78    57    59      194
# Sweden (SWE) [Z]                           22      50    40    54      144
# Switzerland (SUI)                          22      50    40    48      138
# United States (USA) [P] [Q] [R] [Z]        22      96   102    84      282
# Totals                                     22     959   958   948     2865
#
#                                      № Games  01 !.2  02 !.2  03 !.2  \
# Austria (AUT)                             48      77     111     116
# Canada (CAN)                              47     121     155     173
# China (CHN) [CHN]                         19     213     168     145
# Czechoslovakia (TCH) [TCH]                32      51      57      60
# Finland (FIN)                             46     143     146     174
# France (FRA) [O] [P] [Z]                  49     233     254     293
# Germany (GER) [GER] [Z]                   26     252     260     270
# East Germany (GDR) [GDR]                  11     192     165     162
# West Germany (FRG) [FRG]                  11      67      82      94
# Great Britain (GBR) [GBR] [Z]             49     246     276     284
# Italy (ITA) [M] [S]                       48     235     200     228
# Japan (JPN)                               41     140     143     160
# Netherlands (NED) [Z]                     45     114     123     139
# Norway (NOR) [Q]                          46     174     160     143
# Russia (RUS) [RUS]                        11     181     161     177
# Soviet Union (URS) [URS]                  18     473     376     355
# Sweden (SWE) [Z]                          48     193     204     230
# Switzerland (SUI)                         49      97     113     113
# United States (USA) [P] [Q] [R] [Z]       48    1072     859     750
# Totals                                    49    5768    5733    6078
#
#                                      Combined total
# Austria (AUT)                                   304
# Canada (CAN)                                    449
# China (CHN) [CHN]                               526
# Czechoslovakia (TCH) [TCH]                      168
# Finland (FIN)                                   463
# France (FRA) [O] [P] [Z]                        780
# Germany (GER) [GER] [Z]                         782
# East Germany (GDR) [GDR]                        519
# West Germany (FRG) [FRG]                        243
# Great Britain (GBR) [GBR] [Z]                   806
# Italy (ITA) [M] [S]                             663
# Japan (JPN)                                     443
# Netherlands (NED) [Z]                           376
# Norway (NOR) [Q]                                477
# Russia (RUS) [RUS]                              519
# Soviet Union (URS) [URS]                       1204
# Sweden (SWE) [Z]                                627
# Switzerland (SUI)                               323
# United States (USA) [P] [Q] [R] [Z]            2681
# Totals                                        17579

# %% [markdown]
# ## Indexing DataFrames

# %%
# We previously indexed our dataframe with the Country column while reading it in
test = pd.read_excel('Data\olympics.xlsx', skiprows=1,index_col=1)
test.head()
# Out:
#                          Unnamed: 0  № Summer  01 !  02 !  03 !  Total  \
# Afghanistan (AFG)               NaN        13     0     0     2      2
# Algeria (ALG)                   NaN        12     5     2     8     15
# Argentina (ARG)                 NaN        23    18    24    28     70
# Armenia (ARM)                   NaN         5     1     2     9     12
# Australasia (ANZ) [ANZ]         NaN         2     3     4     5     12
#
#                          № Winter  01 !.1  02 !.1  03 !.1  Total.1  № Games  \
# Afghanistan (AFG)               0       0       0       0        0       13
# Algeria (ALG)                   3       0       0       0        0       15
# Argentina (ARG)                18       0       0       0        0       41
# Armenia (ARM)                   6       0       0       0        0       11
# Australasia (ANZ) [ANZ]         0       0       0       0        0        2
#
#                          01 !.2  02 !.2  03 !.2  Combined total
# Afghanistan (AFG)             0       0       2               2
# Algeria (ALG)                 5       2       8              15
# Argentina (ARG)              18      24      28              70
# Armenia (ARM)                 1       2       9              12
# Australasia (ANZ) [ANZ]       3       4       5              12

# %%
# Say we want to change the index from countries to '01 !'
# First we need to preserver the country data
test['Country'] = test.index # Remember index is an attribute of the datafram class not a method so no '()' is required
test.set_index('01 !', inplace=True)

# %%
test.head()
# Out:
#       Unnamed: 0  № Summer  02 !  03 !  Total  № Winter  01 !.1  02 !.1  \
# 01 !
# 0            NaN        13     0     2      2         0       0       0
# 5            NaN        12     2     8     15         3       0       0
# 18           NaN        23    24    28     70        18       0       0
# 1            NaN         5     2     9     12         6       0       0
# 3            NaN         2     4     5     12         0       0       0
#
#       03 !.1  Total.1  № Games  01 !.2  02 !.2  03 !.2  Combined total  \
# 01 !
# 0          0        0       13       0       0       2               2
# 5          0        0       15       5       2       8              15
# 18         0        0       41      18      24      28              70
# 1          0        0       11       1       2       9              12
# 3          0        0        2       3       4       5              12
#
#                       Country
# 01 !
# 0           Afghanistan (AFG)
# 5               Algeria (ALG)
# 18            Argentina (ARG)
# 1               Armenia (ARM)
# 3     Australasia (ANZ) [ANZ]

# %%
# How can we remove the index?
test.reset_index(inplace=True)
test.head()
# Out:
#    01 !  Unnamed: 0  № Summer  02 !  03 !  Total  № Winter  01 !.1  02 !.1  \
# 0     0         NaN        13     0     2      2         0       0       0
# 1     5         NaN        12     2     8     15         3       0       0
# 2    18         NaN        23    24    28     70        18       0       0
# 3     1         NaN         5     2     9     12         6       0       0
# 4     3         NaN         2     4     5     12         0       0       0
#
#    03 !.1  Total.1  № Games  01 !.2  02 !.2  03 !.2  Combined total  \
# 0       0        0       13       0       0       2               2
# 1       0        0       15       5       2       8              15
# 2       0        0       41      18      24      28              70
# 3       0        0       11       1       2       9              12
# 4       0        0        2       3       4       5              12
#
#                    Country
# 0        Afghanistan (AFG)
# 1            Algeria (ALG)
# 2          Argentina (ARG)
# 3            Armenia (ARM)
# 4  Australasia (ANZ) [ANZ]

# %%
# Multilevel indexing
test.set_index((['Country', '02 !']), inplace= True)
test.head()
# Out:
#                               01 !  Unnamed: 0  № Summer  03 !  Total  \
# Country                 02 !
# Afghanistan (AFG)       0        0         NaN        13     2      2
# Algeria (ALG)           2        5         NaN        12     8     15
# Argentina (ARG)         24      18         NaN        23    28     70
# Armenia (ARM)           2        1         NaN         5     9     12
# Australasia (ANZ) [ANZ] 4        3         NaN         2     5     12
#
#                               № Winter  01 !.1  02 !.1  03 !.1  Total.1  \
# Country                 02 !
# Afghanistan (AFG)       0            0       0       0       0        0
# Algeria (ALG)           2            3       0       0       0        0
# Argentina (ARG)         24          18       0       0       0        0
# Armenia (ARM)           2            6       0       0       0        0
# Australasia (ANZ) [ANZ] 4            0       0       0       0        0
#
#                               № Games  01 !.2  02 !.2  03 !.2  Combined total
# Country                 02 !
# Afghanistan (AFG)       0          13       0       0       2               2
# Algeria (ALG)           2          15       5       2       8              15
# Argentina (ARG)         24         41      18      24      28              70
# Armenia (ARM)           2          11       1       2       9              12
# Australasia (ANZ) [ANZ] 4           2       3       4       5              12

# %%
# to query we can select by index using the follwoign command
test.loc[('Afghanistan (AFG)','0'), ('Virgin Islands (ISV)','1')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Afghanistan (AFG)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Afghanistan (AFG)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-cf6cd67f9b94> in <module>()
#       1 # to query we can select by index using the follwoign command
# ----> 2 test.loc[('Afghanistan (AFG)',0), ('Virgin Islands (ISV)',1)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     977         # we may have a nested tuples indexer here
#     978         if self._is_nested_tuple_indexer(tup):
# --> 979             return self._getitem_nested_tuple(tup)
#     980
#     981         # we maybe be using a tuple to represent multiple dimensions here
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_nested_tuple(self, tup)
#    1056
#    1057             current_ndim = obj.ndim
# -> 1058             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1059             axis += 1
#    1060
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1910         # fall thru to straight lookup
#    1911         self._validate_key(key, axis)
# -> 1912         return self._get_label(key, axis=axis)
#    1913
#    1914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     138             raise IndexingError('no slices here, handle elsewhere')
#     139
# --> 140         return self.obj._xs(label, axis=axis)
#     141
#     142     def _get_loc(self, key, axis=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    2983         if isinstance(index, MultiIndex):
#    2984             loc, new_index = self.index.get_loc_level(key,
# -> 2985                                                       drop_level=drop_level)
#    2986         else:
#    2987             loc = self.index.get_loc(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2383                 if len(key) == self.nlevels and self.is_unique:
#    2384                     # Complete key in unique index -> standard get_loc
# -> 2385                     return (self._engine.get_loc(key), None)
#    2386                 else:
#    2387                     return partial_selection(key)
#
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: ('Afghanistan (AFG)', 0)
